# %%
import sys
print("Python version:", sys.version)

import matplotlib.pyplot as plt

import pandas as pd
print("pandas version:", pd.__version__)

import matplotlib
print("matplotlib version:", matplotlib.__version__)

import numpy as np
print("NumPy version:", np.__version__)

import scipy as sp
print("SciPy version:", sp.__version__)

import IPython
print("IPython version:", IPython.__version__)

import vaderSentiment

import json
# Out:
# Python version: 3.6.1 |Anaconda custom (64-bit)| (default, May 11 2017, 13:25:24) [MSC v.1900 64 bit (AMD64)]
# pandas version: 1.0.3
# matplotlib version: 2.0.2
# NumPy version: 1.19.5
# SciPy version: 0.19.0
# IPython version: 6.1.0

# %%
data = json.load(open('chatjson.json',encoding='utf-8'))

# %%
data
# Out:
# {'FileInfo': {'CreatedAt': '2023-02-04T13:44:02.5178998+00:00',
#   'Version': {'Major': 1, 'Minor': 1, 'Patch': 0}},
#  'comments': [{'_id': '8892bad1-05f9-4e92-8692-33c750379d43',
#    'channel_id': '66076836',
#    'commenter': {'_id': '204762872',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'deadcell78',
#     'logo': None,
#     'name': 'deadcell78',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10019.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:48.227Z',
#    'message': {'bits_spent': 0,
#     'body': 'wooo',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'wooo'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': '#9ACD32',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:48.227Z'},
#   {'_id': '21fbc164-bee3-4cf7-bc92-3a590e4ffb03',
#    'channel_id': '66076836',
#    'commenter': {'_id': '676007803',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'twitdoo',
#     'logo': None,
#     'name': 'twitdoo',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10019.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:48.466Z',
#    'message': {'bits_spent': 0,
#     'body': 'BatChest BatChest BatChest BatChest',
#     'emoticons': [{'_id': '115234', 'begin': 0, 'end': 9},
#      {'_id': '115234', 'begin': 9, 'end': 18},
#      {'_id': '115234', 'begin': 18, 'end': 27},
#      {'_id': '115234', 'begin': 27, 'end': 36}],
#     'fragments': [{'emoticon': {'emoticon_id': '115234',
#        'emoticon_set_id': None},
#       'text': 'BatChest'},
#      {'emoticon': None, 'text': ' '},
#      {'emoticon': {'emoticon_id': '115234', 'emoticon_set_id': None},
#       'text': 'BatChest'},
#      {'emoticon': None, 'text': ' '},
#      {'emoticon': {'emoticon_id': '115234', 'emoticon_set_id': None},
#       'text': 'BatChest'},
#      {'emoticon': None, 'text': ' '},
#      {'emoticon': {'emoticon_id': '115234', 'emoticon_set_id': None},
#       'text': 'BatChest'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': None,
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:48.466Z'},
#   {'_id': 'f6f7be47-3987-4a62-85f2-0b83b8f8e314',
#    'channel_id': '66076836',
#    'commenter': {'_id': '415562229',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'riik_h',
#     'logo': None,
#     'name': 'riik_h',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10020.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:49.207Z',
#    'message': {'bits_spent': 0,
#     'body': 'xd',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'xd'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'chatter-cs-go-2022', 'version': '1'}],
#     'user_color': '#1E90FF',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:49.207Z'},
#   {'_id': 'eb9d5aff-8251-43a8-a6f0-8b012af33037',
#    'channel_id': '66076836',
#    'commenter': {'_id': '564677139',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'maazzonn',
#     'logo': None,
#     'name': 'maazzonn',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10020.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:49.476Z',
#    'message': {'bits_spent': 0,
#     'body': 'sheeesh',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'sheeesh'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': '#FF0000',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:49.476Z'},
#   {'_id': '87b3cd54-e70d-46c0-b54f-109be8da9b75',
#    'channel_id': '66076836',
#    'commenter': {'_id': '11889687',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'miguel_teevee',
#     'logo': None,
#     'name': 'miguel_teevee',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10021.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:49.976Z',
#    'message': {'bits_spent': 0,
#     'body': 'JETT DIFFY',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'JETT DIFFY'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'subscriber', 'version': '3'}],
#     'user_color': '#1E90FF',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:49.976Z'},
#   {'_id': '4e8c1608-37d7-49f9-9458-6d83066c3a2f',
#    'channel_id': '66076836',
#    'commenter': {'_id': '205334015',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'torriruu',
#     'logo': None,
#     'name': 'torriruu',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10021.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:50.388Z',
#    'message': {'bits_spent': 0,
#     'body': 'DAMN',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'DAMN'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'predictions', 'version': 'blue-1'},
#      {'_id': 'subscriber', 'version': '0'},
#      {'_id': 'premium', 'version': '1'}],
#     'user_color': '#FFFFFF',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:50.388Z'},
#   {'_id': '9e83220f-b5a6-491f-97ce-b7023c4c810e',
#    'channel_id': '66076836',
#    'commenter': {'_id': '181458752',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'Wandermint',
#     'logo': None,
#     'name': 'wandermint',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10021.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:50.413Z',
#    'message': {'bits_spent': 0,
#     'body': 'Wtf',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'Wtf'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': '#4A4444',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:50.413Z'},
#   {'_id': '7589d592-b1f6-428a-a773-57ee9e4897ea',
#    'channel_id': '66076836',
#    'commenter': {'_id': '143639398',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'stonjn',
#     'logo': None,
#     'name': 'stonjn',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10022.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:51.299Z',
#    'message': {'bits_spent': 0,
#     'body': 'gahhhdamn',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'gahhhdamn'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'premium', 'version': '1'}],
#     'user_color': '#758ED6',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:51.299Z'},
#   {'_id': '34b6aa44-0ea9-4be7-b38a-4a2a5fb2ef82',
#    'channel_id': '66076836',
#    'commenter': {'_id': '61495446',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'TwiggY__',
#     'logo': None,
#     'name': 'twiggy__',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10024.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:53.519Z',
#    'message': {'bits_spent': 0,
#     'body': 'bjnkhbjikbjk',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'bjnkhbjikbjk'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'glhf-pledge', 'version': '1'}],
#     'user_color': '#8E00FF',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:53.519Z'},
#   {'_id': '15728094-8912-4d1f-bc1b-b4bfde183c65',
#    'channel_id': '66076836',
#    'commenter': {'_id': '415562229',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'riik_h',
#     'logo': None,
#     'name': 'riik_h',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10025.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:54.551Z',
#    'message': {'bits_spent': 0,
#     'body': 'bueeeee',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'bueeeee'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'chatter-cs-go-2022', 'version': '1'}],
#     'user_color': '#1E90FF',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:54.551Z'},
#   {'_id': '98f66f12-f293-4015-943b-b87573a866b8',
#    'channel_id': '66076836',
#    'commenter': {'_id': '206202322',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'elchapopires',
#     'logo': None,
#     'name': 'elchapopires',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10026.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:55.445Z',
#    'message': {'bits_spent': 0,
#     'body': 'wtf',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'wtf'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': '#008000',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:55.445Z'},
#   {'_id': '091d504f-287a-4138-adbf-cbe99f4e37f9',
#    'channel_id': '66076836',
#    'commenter': {'_id': '442052165',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'meeseek_ttv',
#     'logo': None,
#     'name': 'meeseek_ttv',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10027.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:56.358Z',
#    'message': {'bits_spent': 0,
#     'body': 'JARSOOOOOO',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'JARSOOOOOO'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'premium', 'version': '1'}],
#     'user_color': '#1AA95A',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:56.358Z'},
#   {'_id': '00f90e5a-9780-4448-892e-ca23acec11a1',
#    'channel_id': '66076836',
#    'commenter': {'_id': '96816504',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'CorporateFoe',
#     'logo': None,
#     'name': 'corporatefoe',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10028.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:56.754Z',
#    'message': {'bits_spent': 0,
#     'body': 'HUH',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'HUH'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': '#FF54DD',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:56.754Z'},
#   {'_id': '72867910-dd31-4ec2-8099-e0f0099a8981',
#    'channel_id': '66076836',
#    'commenter': {'_id': '803534258',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'Unstoppable_Nate',
#     'logo': None,
#     'name': 'unstoppable_nate',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10028.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:56.878Z',
#    'message': {'bits_spent': 0,
#     'body': 'HSJAUAHAHHAHAHAHAHA',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'HSJAUAHAHHAHAHAHAHA'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'chatter-cs-go-2022', 'version': '1'}],
#     'user_color': '#FF69B4',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:56.878Z'},
#   {'_id': 'e265e917-0fd0-4d59-abe2-1a5a6f78387e',
#    'channel_id': '66076836',
#    'commenter': {'_id': '204762872',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'deadcell78',
#     'logo': None,
#     'name': 'deadcell78',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10028.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:56.988Z',
#    'message': {'bits_spent': 0,
#     'body': ':O',
#     'emoticons': [{'_id': '555555580', 'begin': 0, 'end': 3}],
#     'fragments': [{'emoticon': {'emoticon_id': '555555580',
#        'emoticon_set_id': None},
#       'text': ':O'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': '#9ACD32',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:56.988Z'},
#   {'_id': 'fc5151b2-5e9c-4872-9e15-3b479f01a396',
#    'channel_id': '66076836',
#    'commenter': {'_id': '143639398',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'stonjn',
#     'logo': None,
#     'name': 'stonjn',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10028.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:57.047Z',
#    'message': {'bits_spent': 0,
#     'body': 'WTFFF',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'WTFFF'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'premium', 'version': '1'}],
#     'user_color': '#758ED6',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:57.047Z'},
#   {'_id': 'b570f4fe-31c0-456a-bf1d-6648a08485de',
#    'channel_id': '66076836',
#    'commenter': {'_id': '209719813',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'branted',
#     'logo': None,
#     'name': 'branted',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10028.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:57.119Z',
#    'message': {'bits_spent': 0,
#     'body': 'o fuck',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'o fuck'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'vip', 'version': '1'},
#      {'_id': 'subscriber', 'version': '0'},
#      {'_id': 'premium', 'version': '1'}],
#     'user_color': '#0000FF',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:57.119Z'},
#   {'_id': 'e05a97a3-934d-4c27-84c0-9e0ae81842f7',
#    'channel_id': '66076836',
#    'commenter': {'_id': '865715236',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'damian052219',
#     'logo': None,
#     'name': 'damian052219',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10028.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:57.197Z',
#    'message': {'bits_spent': 0,
#     'body': 'ns',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'ns'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': None,
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:57.197Z'},
#   {'_id': '9bcc2c12-46d3-4c5c-b15e-41610847d746',
#    'channel_id': '66076836',
#    'commenter': {'_id': '95156720',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'scatheXD',
#     'logo': None,
#     'name': 'scathexd',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10028.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:57.601Z',
#    'message': {'bits_spent': 0,
#     'body': 'WTF',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'WTF'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'predictions', 'version': 'blue-1'},
#      {'_id': 'subscriber', 'version': '0'},
#      {'_id': 'premium', 'version': '1'}],
#     'user_color': '#00FF6E',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:57.601Z'},
#   {'_id': 'd3f46606-c85b-4bb4-a247-718fd722bf5a',
#    'channel_id': '66076836',
#    'commenter': {'_id': '114570517',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'Greyhound4708',
#     'logo': None,
#     'name': 'greyhound4708',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10028.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:57.61Z',
#    'message': {'bits_spent': 0,
#     'body': 'POG',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'POG'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': '#3000CC',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:57.61Z'},
#   {'_id': '832ca610-f0c8-4858-b946-fc3d3cba8b50',
#    'channel_id': '66076836',
#    'commenter': {'_id': '874934783',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'instalockjettlol',
#     'logo': None,
#     'name': 'instalockjettlol',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10029.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:57.853Z',
#    'message': {'bits_spent': 0,
#     'body': "jett diff yet again'",
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': "jett diff yet again'"}],
#     'is_action': False,
#     'user_badges': [{'_id': 'predictions', 'version': 'blue-1'}],
#     'user_color': None,
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:57.853Z'},
#   {'_id': '5c18a1df-5e61-4716-92dc-a6e501ac2e95',
#    'channel_id': '66076836',
#    'commenter': {'_id': '79685475',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'eldapo',
#     'logo': None,
#     'name': 'eldapo',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10029.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:57.978Z',
#    'message': {'bits_spent': 0,
#     'body': 'wtf',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'wtf'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'premium', 'version': '1'}],
#     'user_color': '#FF4500',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:57.978Z'},
#   {'_id': 'e7e09c9d-3c6c-495d-8798-62840059649b',
#    'channel_id': '66076836',
#    'commenter': {'_id': '105359852',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'richiehedd',
#     'logo': None,
#     'name': 'richiehedd',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10029.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:58.249Z',
#    'message': {'bits_spent': 0,
#     'body': 'Kreygasm',
#     'emoticons': [{'_id': '41', 'begin': 0, 'end': 9}],
#     'fragments': [{'emoticon': {'emoticon_id': '41', 'emoticon_set_id': None},
#       'text': 'Kreygasm'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'moderator', 'version': '1'},
#      {'_id': 'glitchcon2020', 'version': '1'}],
#     'user_color': '#171717',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:58.249Z'},
#   {'_id': '062bc7fe-e8a9-4f88-bd56-0feefa0f4bf4',
#    'channel_id': '66076836',
#    'commenter': {'_id': '102966472',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'Skedoh',
#     'logo': None,
#     'name': 'skedoh',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10029.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:58.462Z',
#    'message': {'bits_spent': 0,
#     'body': 'HES COOKING',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'HES COOKING'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'predictions', 'version': 'blue-1'},
#      {'_id': 'glhf-pledge', 'version': '1'}],
#     'user_color': '#FF0000',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:58.462Z'},
#   {'_id': '98b26c4d-4dc9-4490-9c45-431dba929923',
#    'channel_id': '66076836',
#    'commenter': {'_id': '48018785',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'Cariote123',
#     'logo': None,
#     'name': 'cariote123',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10029.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:58.476Z',
#    'message': {'bits_spent': 0,
#     'body': 'YO LET HIM COOOOK',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'YO LET HIM COOOOK'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': '#00FF7F',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:58.476Z'},
#   {'_id': '29658b1e-9a17-429c-a26d-0abb093d166c',
#    'channel_id': '66076836',
#    'commenter': {'_id': '51794539',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'hawkblazee',
#     'logo': None,
#     'name': 'hawkblazee',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10029.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:58.534Z',
#    'message': {'bits_spent': 0,
#     'body': 'GOT DAMNNNNNNN',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'GOT DAMNNNNNNN'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': '#FF0000',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:58.534Z'},
#   {'_id': '29647096-45a1-404d-bb14-1e39f506dfd8',
#    'channel_id': '66076836',
#    'commenter': {'_id': '135692551',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'justblazetwitch',
#     'logo': None,
#     'name': 'justblazetwitch',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10029.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:58.682Z',
#    'message': {'bits_spent': 0,
#     'body': 'what',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'what'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'subscriber', 'version': '0'},
#      {'_id': 'premium', 'version': '1'}],
#     'user_color': None,
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:58.682Z'},
#   {'_id': 'c5f6a494-1431-4a87-ada2-2f3fc3b48c82',
#    'channel_id': '66076836',
#    'commenter': {'_id': '63712599',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'kwspp',
#     'logo': None,
#     'name': 'kwspp',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10030.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:58.735Z',
#    'message': {'bits_spent': 0,
#     'body': 'wow',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'wow'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': '#DEE41C',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:58.735Z'},
#   {'_id': '3c5874e6-831a-4307-b787-63b306e7fc86',
#    'channel_id': '66076836',
#    'commenter': {'_id': '751621845',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'yyoussef23',
#     'logo': None,
#     'name': 'yyoussef23',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10030.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:58.937Z',
#    'message': {'bits_spent': 0,
#     'body': 'nc',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'nc'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': '#DAA520',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:58.937Z'},
#   {'_id': '2d5a9c69-c322-4562-bcc7-969a6968c16a',
#    'channel_id': '66076836',
#    'commenter': {'_id': '134851601',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'sl33pytomato',
#     'logo': None,
#     'name': 'sl33pytomato',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10030.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:59.068Z',
#    'message': {'bits_spent': 0,
#     'body': 'OMG',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'OMG'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'chatter-cs-go-2022', 'version': '1'}],
#     'user_color': '#DAA520',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:59.068Z'},
#   {'_id': 'aef6a66a-eb5d-4cee-ad56-dd1940f77870',
#    'channel_id': '66076836',
#    'commenter': {'_id': '109551792',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'oxycoppin710',
#     'logo': None,
#     'name': 'oxycoppin710',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10030.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:59.278Z',
#    'message': {'bits_spent': 0,
#     'body': 'sheeeesh',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'sheeeesh'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': '#8A2BE2',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:59.278Z'},
#   {'_id': '1f1ffe9f-82b8-40d0-96ad-af38a700ea06',
#    'channel_id': '66076836',
#    'commenter': {'_id': '869506303',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'hahahhahahahahhaahha',
#     'logo': None,
#     'name': 'hahahhahahahahhaahha',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10030.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:59.377Z',
#    'message': {'bits_spent': 0,
#     'body': 'OMFG',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'OMFG'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': None,
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:59.377Z'},
#   {'_id': 'c5c46720-14d4-4410-a0df-ba9a3606f9e9',
#    'channel_id': '66076836',
#    'commenter': {'_id': '102616225',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'kleincalvin',
#     'logo': None,
#     'name': 'kleincalvin',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10030.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:59.477Z',
#    'message': {'bits_spent': 0,
#     'body': 'shgeeshsh',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'shgeeshsh'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': '#FF0000',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:59.477Z'},
#   {'_id': '446f5b62-6dd1-4e95-b530-49c48f1ce60e',
#    'channel_id': '66076836',
#    'commenter': {'_id': '46734348',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'sirisoo',
#     'logo': None,
#     'name': 'sirisoo',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10030.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:59.533Z',
#    'message': {'bits_spent': 0,
#     'body': 'jesus christ',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'jesus christ'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'glitchcon2020', 'version': '1'}],
#     'user_color': '#B22222',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:59.533Z'},
#   {'_id': '88d4d7aa-42c1-4561-ae11-af4e2838d542',
#    'channel_id': '66076836',
#    'commenter': {'_id': '102966472',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'Skedoh',
#     'logo': None,
#     'name': 'skedoh',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10030.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:59.544Z',
#    'message': {'bits_spent': 0,
#     'body': ':O',
#     'emoticons': [{'_id': '436', 'begin': 0, 'end': 3}],
#     'fragments': [{'emoticon': {'emoticon_id': '436', 'emoticon_set_id': None},
#       'text': ':O'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'predictions', 'version': 'blue-1'},
#      {'_id': 'glhf-pledge', 'version': '1'}],
#     'user_color': '#FF0000',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:59.544Z'},
#   {'_id': '861ccfc4-828b-422c-b0aa-b0f7bd23c072',
#    'channel_id': '66076836',
#    'commenter': {'_id': '605197060',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'ObitZero',
#     'logo': None,
#     'name': 'obitzero',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10031.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:59.823Z',
#    'message': {'bits_spent': 0,
#     'body': 'gadaaamnn',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'gadaaamnn'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': None,
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:59.823Z'},
#   {'_id': '9cb34a90-2585-48d8-98f4-f3f201076e56',
#    'channel_id': '66076836',
#    'commenter': {'_id': '874934783',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'instalockjettlol',
#     'logo': None,
#     'name': 'instalockjettlol',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10031.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:59.863Z',
#    'message': {'bits_spent': 0,
#     'body': 'holy shit',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'holy shit'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'predictions', 'version': 'blue-1'}],
#     'user_color': None,
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:59.863Z'},
#   {'_id': 'f06e0d48-4ea9-46eb-a042-5dbcd5672435',
#    'channel_id': '66076836',
#    'commenter': {'_id': '113805253',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'casa_dilla_',
#     'logo': None,
#     'name': 'casa_dilla_',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10031.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:29:59.944Z',
#    'message': {'bits_spent': 0,
#     'body': 'holy fuck bro',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'holy fuck bro'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'premium', 'version': '1'}],
#     'user_color': None,
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:29:59.944Z'},
#   {'_id': '6127353d-7979-4b70-83d0-a051c2caccac',
#    'channel_id': '66076836',
#    'commenter': {'_id': '803534258',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'Unstoppable_Nate',
#     'logo': None,
#     'name': 'unstoppable_nate',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10031.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:00.132Z',
#    'message': {'bits_spent': 0,
#     'body': 'JARSOOOOOOO',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'JARSOOOOOOO'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'chatter-cs-go-2022', 'version': '1'}],
#     'user_color': '#FF69B4',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:00.132Z'},
#   {'_id': '0d566547-82cd-479b-9977-9878b29b548b',
#    'channel_id': '66076836',
#    'commenter': {'_id': '40980303',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'RAVEthe',
#     'logo': None,
#     'name': 'ravethe',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10031.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:00.289Z',
#    'message': {'bits_spent': 0,
#     'body': 'LETS GO',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'LETS GO'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': None,
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:00.289Z'},
#   {'_id': 'e5959331-5610-4a7e-9d6a-4f26237f9744',
#    'channel_id': '66076836',
#    'commenter': {'_id': '175929868',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'little_milf',
#     'logo': None,
#     'name': 'little_milf',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10031.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:00.304Z',
#    'message': {'bits_spent': 0,
#     'body': 'oh my god',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'oh my god'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'premium', 'version': '1'}],
#     'user_color': '#4163B1',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:00.304Z'},
#   {'_id': '90ba0ada-a0cc-4024-ac61-a9ede711d956',
#    'channel_id': '66076836',
#    'commenter': {'_id': '208301480',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'gjkingethan15400f',
#     'logo': None,
#     'name': 'gjkingethan15400f',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10031.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:00.372Z',
#    'message': {'bits_spent': 0,
#     'body': 'FUNgineer',
#     'emoticons': [{'_id': '244', 'begin': 0, 'end': 10}],
#     'fragments': [{'emoticon': {'emoticon_id': '244', 'emoticon_set_id': None},
#       'text': 'FUNgineer'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'premium', 'version': '1'}],
#     'user_color': None,
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:00.372Z'},
#   {'_id': '985d6046-cc76-4ce9-82e8-b00cc853eb47',
#    'channel_id': '66076836',
#    'commenter': {'_id': '77029379',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'Segabeam',
#     'logo': None,
#     'name': 'segabeam',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10031.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:00.51Z',
#    'message': {'bits_spent': 0,
#     'body': 'BROOOO WTF',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'BROOOO WTF'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': '#5F9EA0',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:00.51Z'},
#   {'_id': 'a11d5aeb-23f2-4da5-a7ba-036860e260a4',
#    'channel_id': '66076836',
#    'commenter': {'_id': '237758564',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'dustyleonn',
#     'logo': None,
#     'name': 'dustyleonn',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10031.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:00.584Z',
#    'message': {'bits_spent': 0,
#     'body': 'pogu',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'pogu'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': '#E5F500',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:00.584Z'},
#   {'_id': '2905cc3d-185a-4206-b6d3-a442ebc12382',
#    'channel_id': '66076836',
#    'commenter': {'_id': '230030482',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'zekevszeke',
#     'logo': None,
#     'name': 'zekevszeke',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10032.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:00.912Z',
#    'message': {'bits_spent': 0,
#     'body': 'filthy',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'filthy'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'premium', 'version': '1'}],
#     'user_color': '#0000FF',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:00.912Z'},
#   {'_id': '37c28bf9-96ba-46c5-8aaa-2465e4d322e4',
#    'channel_id': '66076836',
#    'commenter': {'_id': '179478472',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'Finnnn_E',
#     'logo': None,
#     'name': 'finnnn_e',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10032.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:00.917Z',
#    'message': {'bits_spent': 0,
#     'body': 'enemyc7Ratparty enemyc7Ratparty enemyc7Ratparty enemyc7Ratparty enemyc7Ratparty',
#     'emoticons': [{'_id': 'emotesv2_4eef3b9879c04abfa0f9a253599f125e',
#       'begin': 0,
#       'end': 16},
#      {'_id': 'emotesv2_4eef3b9879c04abfa0f9a253599f125e',
#       'begin': 16,
#       'end': 32},
#      {'_id': 'emotesv2_4eef3b9879c04abfa0f9a253599f125e',
#       'begin': 32,
#       'end': 48},
#      {'_id': 'emotesv2_4eef3b9879c04abfa0f9a253599f125e',
#       'begin': 48,
#       'end': 64},
#      {'_id': 'emotesv2_4eef3b9879c04abfa0f9a253599f125e',
#       'begin': 64,
#       'end': 80}],
#     'fragments': [{'emoticon': {'emoticon_id': 'emotesv2_4eef3b9879c04abfa0f9a253599f125e',
#        'emoticon_set_id': None},
#       'text': 'enemyc7Ratparty'},
#      {'emoticon': None, 'text': ' '},
#      {'emoticon': {'emoticon_id': 'emotesv2_4eef3b9879c04abfa0f9a253599f125e',
#        'emoticon_set_id': None},
#       'text': 'enemyc7Ratparty'},
#      {'emoticon': None, 'text': ' '},
#      {'emoticon': {'emoticon_id': 'emotesv2_4eef3b9879c04abfa0f9a253599f125e',
#        'emoticon_set_id': None},
#       'text': 'enemyc7Ratparty'},
#      {'emoticon': None, 'text': ' '},
#      {'emoticon': {'emoticon_id': 'emotesv2_4eef3b9879c04abfa0f9a253599f125e',
#        'emoticon_set_id': None},
#       'text': 'enemyc7Ratparty'},
#      {'emoticon': None, 'text': ' '},
#      {'emoticon': {'emoticon_id': 'emotesv2_4eef3b9879c04abfa0f9a253599f125e',
#        'emoticon_set_id': None},
#       'text': 'enemyc7Ratparty'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'glhf-pledge', 'version': '1'}],
#     'user_color': '#1E90FF',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:00.917Z'},
#   {'_id': '98783ba0-9d88-466f-95ab-1d2c766daac3',
#    'channel_id': '66076836',
#    'commenter': {'_id': '100309283',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'ben_twitch44',
#     'logo': None,
#     'name': 'ben_twitch44',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10032.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:00.986Z',
#    'message': {'bits_spent': 0,
#     'body': '?',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': '?'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': '#00FF7F',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:00.986Z'},
#   {'_id': '7bed72df-e81f-4ede-bcc9-58736fda2b3a',
#    'channel_id': '66076836',
#    'commenter': {'_id': '100201444',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'JaZZ_CU',
#     'logo': None,
#     'name': 'jazz_cu',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10032.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:01.12Z',
#    'message': {'bits_spent': 0,
#     'body': 'DAMN',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'DAMN'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'premium', 'version': '1'}],
#     'user_color': None,
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:01.12Z'},
#   {'_id': 'edcba612-91a0-40f7-8771-432a59b965a5',
#    'channel_id': '66076836',
#    'commenter': {'_id': '743328167',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': '1eazyyy',
#     'logo': None,
#     'name': '1eazyyy',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10032.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:01.374Z',
#    'message': {'bits_spent': 0,
#     'body': 'WTF',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'WTF'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': None,
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:01.374Z'},
#   {'_id': '1498e137-0621-4026-b0d3-3189b1fb4226',
#    'channel_id': '66076836',
#    'commenter': {'_id': '194831011',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'jhhlots',
#     'logo': None,
#     'name': 'jhhlots',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10032.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:01.41Z',
#    'message': {'bits_spent': 0,
#     'body': 'wat',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'wat'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': None,
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:01.41Z'},
#   {'_id': '5a419d70-f85b-4196-8552-31037553b8d4',
#    'channel_id': '66076836',
#    'commenter': {'_id': '41227652',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'JukeStridewalker',
#     'logo': None,
#     'name': 'jukestridewalker',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10032.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:01.445Z',
#    'message': {'bits_spent': 0,
#     'body': 'Oh damn',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'Oh damn'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'bits-charity', 'version': '1'}],
#     'user_color': '#DAA520',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:01.445Z'},
#   {'_id': 'f03ceb09-0f8d-45ca-a8e8-a2dbc7486c4b',
#    'channel_id': '66076836',
#    'commenter': {'_id': '501990158',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'kubix757',
#     'logo': None,
#     'name': 'kubix757',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10032.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:01.447Z',
#    'message': {'bits_spent': 0,
#     'body': 'pog',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'pog'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'premium', 'version': '1'}],
#     'user_color': '#00FF7F',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:01.447Z'},
#   {'_id': '208e3e1f-2059-4cd8-886f-000a360e228f',
#    'channel_id': '66076836',
#    'commenter': {'_id': '631105313',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'machine_chop',
#     'logo': None,
#     'name': 'machine_chop',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10032.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:01.558Z',
#    'message': {'bits_spent': 0,
#     'body': 'sheeeeeeshhhh',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'sheeeeeeshhhh'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': None,
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:01.558Z'},
#   {'_id': 'bde719f6-b5cf-4421-bcf3-175382a833a8',
#    'channel_id': '66076836',
#    'commenter': {'_id': '207862337',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'Simply_Jo',
#     'logo': None,
#     'name': 'simply_jo',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10032.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:01.61Z',
#    'message': {'bits_spent': 0,
#     'body': 'HOLY FUCK',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'HOLY FUCK'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'subscriber', 'version': '0'}],
# ...
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:02.565Z'},
#   {'_id': '74e9f590-df69-4195-a4c5-ccbc40c28c75',
#    'channel_id': '66076836',
#    'commenter': {'_id': '207847188',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'lexonbee',
#     'logo': None,
#     'name': 'lexonbee',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10034.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:02.98Z',
#    'message': {'bits_spent': 0,
#     'body': 'JARSO',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'JARSO'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'glhf-pledge', 'version': '1'}],
#     'user_color': '#00FF7F',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:02.98Z'},
#   {'_id': 'f03d67a8-ccf8-4d35-beed-b23f98f732a4',
#    'channel_id': '66076836',
#    'commenter': {'_id': '526157096',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'tapiocasideral',
#     'logo': None,
#     'name': 'tapiocasideral',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10034.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:03.003Z',
#    'message': {'bits_spent': 0,
#     'body': 'waaaaaaaaaaaaaaaat',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'waaaaaaaaaaaaaaaat'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'chatter-cs-go-2022', 'version': '1'}],
#     'user_color': '#008000',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:03.003Z'},
#   {'_id': 'e0fde662-3d86-4459-93ed-464571bf3bd8',
#    'channel_id': '66076836',
#    'commenter': {'_id': '227570867',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'kumanixx',
#     'logo': None,
#     'name': 'kumanixx',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10034.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:03.559Z',
#    'message': {'bits_spent': 0,
#     'body': 'oh myyy',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'oh myyy'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'premium', 'version': '1'}],
#     'user_color': '#FF69B4',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:03.559Z'},
#   {'_id': 'cc1b115e-da1e-408b-bd98-8b90fb667806',
#    'channel_id': '66076836',
#    'commenter': {'_id': '98541945',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'Kedzal__',
#     'logo': None,
#     'name': 'kedzal__',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10034.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:03.564Z',
#    'message': {'bits_spent': 0,
#     'body': 'OMG',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'OMG'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'predictions', 'version': 'blue-1'}],
#     'user_color': None,
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:03.564Z'},
#   {'_id': 'd60b1683-da33-4d98-9dfe-906e28a0f758',
#    'channel_id': '66076836',
#    'commenter': {'_id': '772613933',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'ngheeeeee',
#     'logo': None,
#     'name': 'ngheeeeee',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10034.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:03.65Z',
#    'message': {'bits_spent': 0,
#     'body': 'clean af',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'clean af'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'predictions', 'version': 'blue-1'}],
#     'user_color': '#1E90FF',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:03.65Z'},
#   {'_id': '4d01da4e-612b-4171-8f5d-f5298720f1a5',
#    'channel_id': '66076836',
#    'commenter': {'_id': '679014784',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'JuliennTwitch',
#     'logo': None,
#     'name': 'julienntwitch',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10035.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:03.72Z',
#    'message': {'bits_spent': 0,
#     'body': '<3',
#     'emoticons': [{'_id': '555555584', 'begin': 0, 'end': 3}],
#     'fragments': [{'emoticon': {'emoticon_id': '555555584',
#        'emoticon_set_id': None},
#       'text': '<3'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': '#00FF7F',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:03.72Z'},
#   {'_id': '62cd14ef-e048-4519-9587-37ba7e150c19',
#    'channel_id': '66076836',
#    'commenter': {'_id': '104277759',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'matthewz99',
#     'logo': None,
#     'name': 'matthewz99',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10035.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:03.888Z',
#    'message': {'bits_spent': 0,
#     'body': 'WE SEE YOU',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'WE SEE YOU'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'premium', 'version': '1'}],
#     'user_color': '#1E90FF',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:03.888Z'},
#   {'_id': 'a80f8233-72ea-45c5-a763-e78eeafb3d1f',
#    'channel_id': '66076836',
#    'commenter': {'_id': '676007803',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'twitdoo',
#     'logo': None,
#     'name': 'twitdoo',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10035.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:03.937Z',
#    'message': {'bits_spent': 0,
#     'body': 'HOW BRUHHHHHHHHHHHHHHH',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'HOW BRUHHHHHHHHHHHHHHH'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': None,
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:03.937Z'},
#   {'_id': 'e6e27fab-8687-4da7-bfcd-7e342a3d7353',
#    'channel_id': '66076836',
#    'commenter': {'_id': '204762872',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'deadcell78',
#     'logo': None,
#     'name': 'deadcell78',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10035.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:04.003Z',
#    'message': {'bits_spent': 0,
#     'body': ':O :O',
#     'emoticons': [{'_id': '555555580', 'begin': 0, 'end': 3},
#      {'_id': '555555580', 'begin': 3, 'end': 6}],
#     'fragments': [{'emoticon': {'emoticon_id': '555555580',
#        'emoticon_set_id': None},
#       'text': ':O'},
#      {'emoticon': None, 'text': ' '},
#      {'emoticon': {'emoticon_id': '555555580', 'emoticon_set_id': None},
#       'text': ':O'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': '#9ACD32',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:04.003Z'},
#   {'_id': 'b2787437-00c8-473d-8e38-fd03b9bbc21d',
#    'channel_id': '66076836',
#    'commenter': {'_id': '29868133',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'yesac99',
#     'logo': None,
#     'name': 'yesac99',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10035.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:04.082Z',
#    'message': {'bits_spent': 0,
#     'body': 'Clip that',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'Clip that'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'premium', 'version': '1'}],
#     'user_color': '#FF4EAD',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:04.082Z'},
#   {'_id': '263b90c2-583f-4060-8306-7103b8cd79a5',
#    'channel_id': '66076836',
#    'commenter': {'_id': '422072219',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'mendouksaii',
#     'logo': None,
#     'name': 'mendouksaii',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10035.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:04.092Z',
#    'message': {'bits_spent': 0,
#     'body': 'SHMMOOOOOVEMENT',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'SHMMOOOOOVEMENT'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'subscriber', 'version': '3'}],
#     'user_color': '#5F9EA0',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:04.092Z'},
#   {'_id': 'd3d1f757-f87a-4892-9290-640db173aab5',
#    'channel_id': '66076836',
#    'commenter': {'_id': '557946099',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'youlovejd',
#     'logo': None,
#     'name': 'youlovejd',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10035.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:04.206Z',
#    'message': {'bits_spent': 0,
#     'body': 'wtfffff',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'wtfffff'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': '#1E90FF',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:04.206Z'},
#   {'_id': '3e4dc087-e32e-4770-ae7b-484fa7c8b3c3',
#    'channel_id': '66076836',
#    'commenter': {'_id': '75135187',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'c0us33',
#     'logo': None,
#     'name': 'c0us33',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10035.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:04.245Z',
#    'message': {'bits_spent': 0,
#     'body': '!Sens',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': '!Sens'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'subscriber', 'version': '0'},
#      {'_id': 'premium', 'version': '1'}],
#     'user_color': None,
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:04.245Z'},
#   {'_id': '90fd475d-994b-4ec0-b118-8043f7d689be',
#    'channel_id': '66076836',
#    'commenter': {'_id': '56535999',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'rampage21',
#     'logo': None,
#     'name': 'rampage21',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10035.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:04.26Z',
#    'message': {'bits_spent': 0,
#     'body': 'Pog',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'Pog'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'premium', 'version': '1'}],
#     'user_color': '#0098FF',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:04.26Z'},
#   {'_id': 'cecf2ab7-b228-4b7c-a57e-fa89302befe8',
#    'channel_id': '66076836',
#    'commenter': {'_id': '24005226',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'jayyj0294',
#     'logo': None,
#     'name': 'jayyj0294',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10035.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:04.269Z',
#    'message': {'bits_spent': 0,
#     'body': 'sheeshhh!!',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'sheeshhh!!'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'premium', 'version': '1'}],
#     'user_color': '#FF69B4',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:04.269Z'},
#   {'_id': '65c51df4-5111-4d73-bd11-b086afcbad6c',
#    'channel_id': '66076836',
#    'commenter': {'_id': '237719657',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'Fossabot',
#     'logo': None,
#     'name': 'fossabot',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10035.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:04.405Z',
#    'message': {'bits_spent': 0,
#     'body': '⚙️ CSGO: 2 @400dpi | Valorant: 0.75 @400dpi',
#     'emoticons': [],
#     'fragments': [{'emoticon': None,
#       'text': '⚙️ CSGO: 2 @400dpi | Valorant: 0.75 @400dpi'}],
#     'is_action': False,
#     'user_badges': [{'_id': 'moderator', 'version': '1'},
#      {'_id': 'partner', 'version': '1'}],
#     'user_color': '#1976D2',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:04.405Z'},
#   {'_id': 'a5fa5915-9735-45b4-86d8-0b4891dede1a',
#    'channel_id': '66076836',
#    'commenter': {'_id': '840020027',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'omartrx1',
#     'logo': None,
#     'name': 'omartrx1',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10035.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:04.667Z',
#    'message': {'bits_spent': 0,
#     'body': 'ns',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'ns'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': None,
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:04.667Z'},
#   {'_id': '1210e0a2-bd14-4525-ad06-fabea4848937',
#    'channel_id': '66076836',
#    'commenter': {'_id': '114570517',
#     'bio': None,
#     'created_at': '0001-01-01T00:00:00',
#     'display_name': 'Greyhound4708',
#     'logo': None,
#     'name': 'greyhound4708',
#     'type': 'user',
#     'updated_at': '0001-01-01T00:00:00'},
#    'content_id': '1722408853',
#    'content_offset_seconds': 10036.0,
#    'content_type': 'video',
#    'created_at': '2023-01-29T23:30:04.976Z',
#    'message': {'bits_spent': 0,
#     'body': 'SHEEEEEEEEESH',
#     'emoticons': [],
#     'fragments': [{'emoticon': None, 'text': 'SHEEEEEEEEESH'}],
#     'is_action': False,
#     'user_badges': [],
#     'user_color': '#3000CC',
#     'user_notice_params': None},
#    'more_replies': False,
#    'source': 'chat',
#    'state': 'published',
#    'updated_at': '2023-01-29T23:30:04.976Z'}],
#  'embeddedData': None,
#  'streamer': {'id': 66076836, 'name': 'Stewie2K'},
#  'video': {'created_at': '2023-01-29T23:30:02Z',
#   'end': 10036.0,
#   'id': '1722408853',
#   'length': 26.0,
#   'start': 10010.0,
#   'title': 'Ewwwwwwwwww!'}}

# %%
df = pd.DataFrame(data["comments"])

# %%
df
# Out:
#                                      _id                created_at  \
# 0   8892bad1-05f9-4e92-8692-33c750379d43  2023-01-29T23:29:48.227Z
# 1   21fbc164-bee3-4cf7-bc92-3a590e4ffb03  2023-01-29T23:29:48.466Z
# 2   f6f7be47-3987-4a62-85f2-0b83b8f8e314  2023-01-29T23:29:49.207Z
# 3   eb9d5aff-8251-43a8-a6f0-8b012af33037  2023-01-29T23:29:49.476Z
# 4   87b3cd54-e70d-46c0-b54f-109be8da9b75  2023-01-29T23:29:49.976Z
# ..                                   ...                       ...
# 71  90fd475d-994b-4ec0-b118-8043f7d689be   2023-01-29T23:30:04.26Z
# 72  cecf2ab7-b228-4b7c-a57e-fa89302befe8  2023-01-29T23:30:04.269Z
# 73  65c51df4-5111-4d73-bd11-b086afcbad6c  2023-01-29T23:30:04.405Z
# 74  a5fa5915-9735-45b4-86d8-0b4891dede1a  2023-01-29T23:30:04.667Z
# 75  1210e0a2-bd14-4525-ad06-fabea4848937  2023-01-29T23:30:04.976Z
#
#                   updated_at channel_id content_type  content_id  \
# 0   2023-01-29T23:29:48.227Z   66076836        video  1722408853
# 1   2023-01-29T23:29:48.466Z   66076836        video  1722408853
# 2   2023-01-29T23:29:49.207Z   66076836        video  1722408853
# 3   2023-01-29T23:29:49.476Z   66076836        video  1722408853
# 4   2023-01-29T23:29:49.976Z   66076836        video  1722408853
# ..                       ...        ...          ...         ...
# 71   2023-01-29T23:30:04.26Z   66076836        video  1722408853
# 72  2023-01-29T23:30:04.269Z   66076836        video  1722408853
# 73  2023-01-29T23:30:04.405Z   66076836        video  1722408853
# 74  2023-01-29T23:30:04.667Z   66076836        video  1722408853
# 75  2023-01-29T23:30:04.976Z   66076836        video  1722408853
#
#     content_offset_seconds                                          commenter  \
# 0                  10019.0  {'display_name': 'deadcell78', '_id': '2047628...
# 1                  10019.0  {'display_name': 'twitdoo', '_id': '676007803'...
# 2                  10020.0  {'display_name': 'riik_h', '_id': '415562229',...
# 3                  10020.0  {'display_name': 'maazzonn', '_id': '564677139...
# 4                  10021.0  {'display_name': 'miguel_teevee', '_id': '1188...
# ..                     ...                                                ...
# 71                 10035.0  {'display_name': 'rampage21', '_id': '56535999...
# 72                 10035.0  {'display_name': 'jayyj0294', '_id': '24005226...
# 73                 10035.0  {'display_name': 'Fossabot', '_id': '237719657...
# 74                 10035.0  {'display_name': 'omartrx1', '_id': '840020027...
# 75                 10036.0  {'display_name': 'Greyhound4708', '_id': '1145...
#
#    source      state                                            message  \
# 0    chat  published  {'body': 'wooo', 'bits_spent': 0, 'fragments':...
# 1    chat  published  {'body': 'BatChest BatChest BatChest BatChest'...
# 2    chat  published  {'body': 'xd', 'bits_spent': 0, 'fragments': [...
# 3    chat  published  {'body': 'sheeesh', 'bits_spent': 0, 'fragment...
# 4    chat  published  {'body': 'JETT DIFFY', 'bits_spent': 0, 'fragm...
# ..    ...        ...                                                ...
# 71   chat  published  {'body': 'Pog', 'bits_spent': 0, 'fragments': ...
# 72   chat  published  {'body': 'sheeshhh!!', 'bits_spent': 0, 'fragm...
# 73   chat  published  {'body': '⚙️ CSGO: 2 @400dpi | Valorant: 0.75 ...
# 74   chat  published  {'body': 'ns', 'bits_spent': 0, 'fragments': [...
# 75   chat  published  {'body': 'SHEEEEEEEEESH', 'bits_spent': 0, 'fr...
#
#     more_replies
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ..           ...
# 71         False
# 72         False
# 73         False
# 74         False
# 75         False
#
# [76 rows x 12 columns]

# %%
d = {'message': pd.json_normalize(df.message).body, 'time':df.content_offset_seconds}

# %%
df = pd.DataFrame(data=d)

# %%
df
# Out:
#                                         message  time
# 0                                          wooo   0.0
# 1           BatChest BatChest BatChest BatChest   0.0
# 2                                            xd   1.0
# 3                                       sheeesh   1.0
# 4                                    JETT DIFFY   2.0
# ..                                          ...   ...
# 71                                          Pog  16.0
# 72                                   sheeshhh!!  16.0
# 73  ⚙️ CSGO: 2 @400dpi | Valorant: 0.75 @400dpi  16.0
# 74                                           ns  16.0
# 75                                SHEEEEEEEEESH  17.0
#
# [76 rows x 2 columns]

# %% [markdown]
# Preprocessing

# %% [markdown]
# # Combining lexicons

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
Analyser = SentimentIntensityAnalyzer() ##create analyser

# %% [markdown]
# ## Merge Top 100 Twitch emotes with sentiment into lexicon

# %%
emotelex = pd.read_csv('emote_average.tsv',sep='\t') ##read twitch emote tsv into dataframe
emotelex['word'] = emotelex['word'].str.lower() ##lower case as it has to be to be inserted into lexicon
emotedict = dict(zip(emotelex.word, emotelex.sentiment)) ##convert dataframe to dictionary 
emojilex = pd.read_csv('emoji_average.tsv',sep='\t') ##read twitch emoji tsv into dataframe
emojidict = dict(zip(emojilex.word, emojilex.sentiment)) ##convert dataframe to dictionary 
emojidict
# Out:
# {'©': 0.12,
#  '®': 0.28,
#  '↾': 0.67,
#  '↿': 0.67,
#  '━': 0.18,
#  '│': 0.35,
#  '┊': 1.0,
#  '═': 0.02,
#  '║': 0.15,
#  '╭': 0.17,
#  '╮': 0.13,
#  '╯': -0.01,
#  '█': -0.03,
#  '░': -0.05,
#  '▓': 0.01,
#  '▪': 0.2,
#  '▬': 0.48,
#  '▶': 0.21,
#  '►': 0.16,
#  '●': 0.18,
#  '☀': 0.47,
#  '☁': 0.32,
#  '★': 0.28,
#  '☆': 0.43,
#  '☑': 0.1,
#  '☔': 0.3,
#  '☕': 0.25,
#  '☝': 0.31,
#  '☞': 0.12,
#  '☯': 0.0,
#  '☷': 0.06,
#  '☺': 0.66,
#  '♡': 0.67,
#  '♥': 0.66,
#  '♦': 0.48,
#  '♪': 0.54,
#  '♫': 0.29,
#  '⚠': -0.07,
#  '⚡': 0.18,
#  '⚽': 0.62,
#  '⛄': 0.53,
#  '⛔': 0.51,
#  '✂': -0.48,
#  '✅': 0.43,
#  '✈': 0.42,
#  '✊': 0.43,
#  '✋': 0.13,
#  '✌': 0.46,
#  '✓': 0.3,
#  '✔': 0.27,
#  '✖': 0.32,
#  '✧': 0.34,
#  '✨': 0.35,
#  '✿': 0.4,
#  '❄': 0.51,
#  '❌': 0.29,
#  '❗': 0.1,
#  '❤': 0.75,
#  '➜': 0.16,
#  '➡': 0.15,
#  '⭐': 0.59,
#  '￼': -0.49,
#  '�': 0.09,
#  '🇩': 0.65,
#  '🇪': 0.63,
#  '🇸': 0.53,
#  '🇺': 0.56,
#  '🌀': 0.11,
#  '🌃': 0.41,
#  '🌈': 0.53,
#  '🌊': 0.52,
#  '🌍': 0.62,
#  '🌙': 0.62,
#  '🌚': 0.47,
#  '🌞': 0.57,
#  '🌟': 0.33,
#  '🌴': 0.53,
#  '🌷': 0.55,
#  '🌸': 0.65,
#  '🌹': 0.61,
#  '🌺': 0.56,
#  '🌻': 0.59,
#  '🌼': 0.81,
#  '🌿': 0.39,
#  '🍀': 0.29,
#  '🍁': 0.49,
#  '🍂': 0.56,
#  '🍃': 0.38,
#  '🍆': 0.42,
#  '🍉': 0.61,
#  '🍌': 0.45,
#  '🍓': 0.69,
#  '🍔': 0.29,
#  '🍕': 0.42,
#  '🍝': 0.12,
#  '🍟': 0.31,
#  '🍣': -0.25,
#  '🍦': 0.47,
#  '🍩': 0.39,
#  '🍪': 0.33,
#  '🍫': 0.16,
#  '🍭': 0.32,
#  '🍰': 0.46,
#  '🍴': 0.55,
#  '🍷': 0.4,
#  '🍸': 0.55,
#  '🍹': 0.67,
#  '🍺': 0.5,
#  '🍻': 0.52,
#  '🎀': 0.64,
#  '🎁': 0.77,
#  '🎂': 0.62,
#  '🎃': 0.62,
#  '🎄': 0.54,
#  '🎅': 0.32,
#  '🎆': 0.75,
#  '🎈': 0.73,
#  '🎉': 0.74,
#  '🎊': 0.73,
#  '🎎': 0.96,
#  '🎓': 0.58,
#  '🎤': 0.49,
#  '🎥': 0.3,
#  '🎧': 0.42,
#  '🎮': 0.44,
#  '🎵': 0.51,
#  '🎶': 0.54,
#  '🎸': 0.53,
#  '🏀': 0.27,
#  '🏃': 0.41,
#  '🏆': 0.74,
#  '🏈': 0.54,
#  '🏊': 0.6,
#  '🐒': 0.54,
#  '🐓': 0.03,
#  '🐟': 0.72,
#  '🐣': 0.49,
#  '🐥': 0.61,
#  '🐧': 0.46,
#  '🐯': 0.49,
#  '🐰': 0.62,
#  '🐱': 0.53,
#  '🐶': 0.59,
#  '🐷': 0.38,
#  '🐸': -0.08,
#  '🐼': 0.27,
#  '🐾': 0.63,
#  '👀': 0.06,
#  '👄': 0.49,
#  '👅': 0.47,
#  '👆': 0.33,
#  '👇': 0.26,
#  '👈': 0.43,
#  '👉': 0.39,
#  '👊': 0.23,
#  '👋': 0.42,
#  '👌': 0.56,
#  '👍': 0.52,
#  '👎': -0.19,
#  '👏': 0.52,
#  '👐': -0.02,
#  '👑': 0.7,
#  '👣': 0.36,
#  '👪': -0.02,
#  '👫': 0.26,
#  '👬': -0.06,
#  '👭': 0.47,
#  '👯': 0.45,
#  '👶': 0.45,
#  '👸': 0.62,
#  '👻': 0.23,
#  '👼': 0.34,
#  '👽': 0.32,
#  '👾': 0.37,
#  '👿': -0.56,
#  '💀': -0.21,
#  '💁': 0.33,
#  '💃': 0.74,
#  '💄': 0.45,
#  '💅': 0.4,
#  '💆': 0.23,
#  '💉': 0.38,
#  '💊': 0.45,
#  '💋': 0.69,
#  '💍': 0.49,
#  '💎': 0.57,
#  '💏': 0.39,
#  '💐': 0.76,
#  '💑': 0.68,
#  '💓': 0.67,
#  '💔': -0.12,
#  '💕': 0.63,
#  '💖': 0.71,
#  '💗': 0.66,
#  '💘': 0.69,
#  '💙': 0.73,
#  '💚': 0.66,
#  '💛': 0.71,
#  '💜': 0.66,
#  '💝': 0.66,
#  '💞': 0.74,
#  '💟': 0.71,
#  '💣': 0.01,
#  '💤': 0.37,
#  '💥': 0.15,
#  '💦': 0.48,
#  '💨': 0.39,
#  '💩': -0.12,
#  '💪': 0.56,
#  '💫': 0.51,
#  '💭': 0.22,
#  '💯': 0.12,
#  '💰': 0.26,
#  '💸': 0.17,
#  '📒': 0.04,
#  '📖': 0.18,
#  '📚': 0.34,
#  '📝': 0.24,
#  '📷': 0.45,
#  '🔝': 0.48,
#  '🔥': 0.14,
#  '🔪': 0.07,
#  '🔫': -0.2,
#  '🔮': 0.27,
#  '🗿': 0.47,
#  '😀': 0.57,
#  '😁': 0.45,
#  '😂': 0.22,
#  '😃': 0.56,
#  '😄': 0.42,
#  '😅': 0.18,
#  '😆': 0.41,
#  '😇': 0.6,
#  '😈': 0.27,
#  '😉': 0.46,
#  '😊': 0.64,
#  '😋': 0.63,
#  '😌': 0.48,
#  '😍': 0.68,
#  '😎': 0.49,
#  '😏': 0.33,
#  '😐': -0.39,
#  '😑': -0.31,
#  '😒': -0.37,
#  '😓': -0.08,
#  '😔': -0.15,
#  '😕': -0.4,
#  '😖': -0.16,
#  '😘': 0.7,
#  '😙': 0.79,
#  '😚': 0.71,
#  '😛': 0.61,
#  '😜': 0.46,
#  '😝': 0.43,
#  '😞': -0.12,
#  '😟': 0.07,
#  '😠': -0.3,
#  '😡': -0.64,
#  '😢': 0.01,
#  '😣': -0.21,
#  '😤': -0.21,
#  '😥': 0.12,
#  '😦': -0.39,
#  '😧': -0.07,
#  '😨': -0.14,
#  '😩': -0.37,
#  '😪': -0.08,
#  '😫': -0.15,
#  '😬': 0.2,
#  '😭': -0.09,
#  '😮': 0.28,
#  '😯': 0.13,
#  '😰': -0.02,
#  '😱': 0.19,
#  '😲': -0.07,
#  '😳': 0.02,
#  '😴': -0.08,
#  '😵': 0.09,
#  '😶': -0.15,
#  '😷': -0.17,
#  '😸': 0.42,
#  '😹': 0.14,
#  '😻': 0.62,
#  '😽': 0.59,
#  '😿': -0.38,
#  '🙀': 0.34,
#  '🙅': -0.21,
#  '🙆': 0.51,
#  '🙇': 0.14,
#  '🙈': 0.43,
#  '🙉': 0.34,
#  '🙊': 0.46,
#  '🙋': 0.49,
#  '🙌': 0.56,
#  '🙏': 0.42,
#  '🚗': 0.24,
#  '🚨': 0.67,
#  '🚫': -0.45,
#  '🚬': 0.54,
#  '🚶': -0.15}

# %%
Analyser.lexicon.update(emotedict) ##merge lexicons together
Analyser.lexicon.update(emojidict) ##merge lexicons together

# %%
Analyser.lexicon
# Out:
# {'$:': -1.5,
#  '%)': -0.4,
#  '%-)': -1.5,
#  '&-:': -0.4,
#  '&:': -0.7,
#  "( '}{' )": 1.6,
#  '(%': -0.9,
#  "('-:": 2.2,
#  "(':": 2.3,
#  '((-:': 2.1,
#  '(*': 1.1,
#  '(-%': -0.7,
#  '(-*': 1.3,
#  '(-:': 1.6,
#  '(-:0': 2.8,
#  '(-:<': -0.4,
#  '(-:o': 1.5,
#  '(-:O': 1.5,
#  '(-:{': -0.1,
#  '(-:|>*': 1.9,
#  '(-;': 1.3,
#  '(-;|': 2.1,
#  '(8': 2.6,
#  '(:': 2.2,
#  '(:0': 2.4,
#  '(:<': -0.2,
#  '(:o': 2.5,
#  '(:O': 2.5,
#  '(;': 1.1,
#  '(;<': 0.3,
#  '(=': 2.2,
#  '(?:': 2.1,
#  '(^:': 1.5,
#  '(^;': 1.5,
#  '(^;0': 2.0,
#  '(^;o': 1.9,
#  '(o:': 1.6,
#  ")':": -2.0,
#  ")-':": -2.1,
#  ')-:': -2.1,
#  ')-:<': -2.2,
#  ')-:{': -2.1,
#  '):': -1.8,
#  '):<': -1.9,
#  '):{': -2.3,
#  ');<': -2.6,
#  '*)': 0.6,
#  '*-)': 0.3,
#  '*-:': 2.1,
#  '*-;': 2.4,
#  '*:': 1.9,
#  '*<|:-)': 1.6,
#  '*\\0/*': 2.3,
#  '*^:': 1.6,
#  ',-:': 1.2,
#  "---'-;-{@": 2.3,
#  '--<--<@': 2.2,
#  '.-:': -1.2,
#  '..###-:': -1.7,
#  '..###:': -1.9,
#  '/-:': -1.3,
#  '/:': -1.3,
#  '/:<': -1.4,
#  '/=': -0.9,
#  '/^:': -1.0,
#  '/o:': -1.4,
#  '0-8': 0.1,
#  '0-|': -1.2,
#  '0:)': 1.9,
#  '0:-)': 1.4,
#  '0:-3': 1.5,
#  '0:03': 1.9,
#  '0;^)': 1.6,
#  '0_o': -0.3,
#  '10q': 2.1,
#  '1337': 2.1,
#  '143': 3.2,
#  '1432': 2.6,
#  '14aa41': 2.4,
#  '182': -2.9,
#  '187': -3.1,
#  '2g2b4g': 2.8,
#  '2g2bt': -0.1,
#  '2qt': 2.1,
#  '3:(': -2.2,
#  '3:)': 0.5,
#  '3:-(': -2.3,
#  '3:-)': -1.4,
#  '4col': -2.2,
#  '4q': -3.1,
#  '5fs': 1.5,
#  '8)': 1.9,
#  '8-d': 1.7,
#  '8-o': -0.3,
#  '86': -1.6,
#  '8d': 2.9,
#  ':###..': -2.4,
#  ':$': -0.2,
#  ':&': -0.6,
#  ":'(": -2.2,
#  ":')": 2.3,
#  ":'-(": -2.4,
#  ":'-)": 2.7,
#  ':(': -0.61,
#  ':)': 0.75,
#  ':*': 2.5,
#  ':-###..': -2.5,
#  ':-&': -0.5,
#  ':-(': -1.5,
#  ':-)': 1.3,
#  ':-))': 2.8,
#  ':-*': 1.7,
#  ':-,': 1.1,
#  ':-.': -0.9,
#  ':-/': -1.2,
#  ':-<': -1.5,
#  ':-d': 2.3,
#  ':-D': 2.3,
#  ':-o': 0.1,
#  ':-p': 1.5,
#  ':-[': -1.6,
#  ':-\\': -0.9,
#  ':-c': -1.3,
#  ':-|': -0.7,
#  ':-||': -2.5,
#  ':-Þ': 0.9,
#  ':/': -1.4,
#  ':3': 2.3,
#  ':<': -2.1,
#  ':>': 2.1,
#  ':?)': 1.3,
#  ':?c': -1.6,
#  ':@': -2.5,
#  ':d': 0.87,
#  ':D': 2.3,
#  ':l': -1.7,
#  ':o': 0.06,
#  ':p': 0.27,
#  ':s': -1.2,
#  ':[': -2.0,
#  ':\\': -1.3,
#  ':]': 2.2,
#  ':^)': 2.1,
#  ':^*': 2.6,
#  ':^/': -1.2,
#  ':^\\': -1.0,
#  ':^|': -1.0,
#  ':c': -2.1,
#  ':c)': 2.0,
#  ':o)': 2.1,
#  ':o/': -1.4,
#  ':o\\': -1.1,
#  ':o|': -0.6,
#  ':P': 1.4,
#  ':{': -1.9,
#  ':|': -0.4,
#  ':}': 2.1,
#  ':Þ': 1.1,
#  ';)': 0.56,
#  ';-)': 1.0,
#  ';-*': 2.2,
#  ';-]': 0.7,
#  ';d': 0.8,
#  ';D': 0.8,
#  ';]': 0.6,
#  ';^)': 1.4,
#  '</3': -3.0,
#  '<3': 0.94,
#  '<:': 2.1,
#  '<:-|': -1.4,
#  '=)': 2.2,
#  '=-3': 2.0,
#  '=-d': 2.4,
#  '=-D': 2.4,
#  '=/': -1.4,
#  '=3': 2.1,
#  '=d': 2.3,
#  '=D': 2.3,
#  '=l': -1.2,
#  '=\\': -1.2,
#  '=]': 1.6,
#  '=p': 1.3,
#  '=|': -0.8,
#  '>-:': -2.0,
#  '>.<': -1.3,
#  '>:': -2.1,
#  '>:(': -2.7,
#  '>:)': 0.4,
#  '>:-(': -2.7,
#  '>:-)': -0.4,
#  '>:/': -1.6,
#  '>:o': -1.2,
#  '>:p': 1.0,
#  '>:[': -2.1,
#  '>:\\': -1.7,
#  '>;(': -2.9,
#  '>;)': 0.1,
#  '>_>^': 2.1,
#  '@:': -2.1,
#  '@>-->--': 2.1,
#  "@}-;-'---": 2.2,
#  'aas': 2.5,
#  'aayf': 2.7,
#  'afu': -2.9,
#  'alol': 2.8,
#  'ambw': 2.9,
#  'aml': 3.4,
#  'atab': -1.9,
#  'awol': -1.3,
#  'ayc': 0.2,
#  'ayor': -1.2,
#  'aug-00': 0.3,
#  'bfd': -2.7,
#  'bfe': -2.6,
#  'bff': 2.9,
#  'bffn': 1.0,
#  'bl': 2.3,
#  'bsod': -2.2,
#  'btd': -2.1,
#  'btdt': -0.1,
#  'bz': 0.4,
#  'b^d': 2.6,
#  'cwot': -2.3,
#  "d-':": -2.5,
#  'd8': -3.2,
#  'd:': -0.47,
#  'd:<': -3.2,
#  'd;': -2.9,
#  'd=': 1.5,
#  'doa': -2.3,
#  'dx': -3.0,
#  'ez': 0.58,
#  'fav': 2.0,
#  'fcol': -1.8,
#  'ff': 1.8,
#  'ffs': -2.8,
#  'fkm': -2.4,
#  'foaf': 1.8,
#  'ftw': 2.0,
#  'fu': -3.7,
#  'fubar': -3.0,
#  'fwb': 2.5,
#  'fyi': 0.8,
#  'fysa': 0.4,
#  'g1': 1.4,
#  'gg': 1.2,
#  'gga': 1.7,
#  'gigo': -0.6,
#  'gj': 2.0,
#  'gl': 1.3,
#  'gla': 2.5,
#  'gn': 1.2,
#  'gr8': 2.7,
#  'grrr': -0.4,
#  'gt': 1.1,
#  'h&k': 2.3,
#  'hagd': 2.2,
#  'hagn': 2.2,
#  'hago': 1.2,
#  'hak': 1.9,
#  'hand': 2.2,
#  'heart': 3.2,
#  'hearts': 3.3,
#  'hho1/2k': 1.4,
#  'hhoj': 2.0,
#  'hhok': 0.9,
#  'hugz': 2.0,
#  'hi5': 1.9,
#  'idk': -0.4,
#  'ijs': 0.7,
#  'ilu': 3.4,
#  'iluaaf': 2.7,
#  'ily': 3.4,
#  'ily2': 2.6,
#  'iou': 0.7,
#  'iyq': 2.3,
#  'j/j': 2.0,
#  'j/k': 1.6,
#  'j/p': 1.4,
#  'j/t': -0.2,
#  'j/w': 1.0,
#  'j4f': 1.4,
#  'j4g': 1.7,
#  'jho': 0.8,
#  'jhomf': 1.0,
#  'jj': 1.0,
#  'jk': 0.9,
#  'jp': 0.8,
#  'jt': 0.9,
#  'jw': 1.6,
#  'jealz': -1.2,
#  'k4y': 2.3,
#  'kfy': 2.3,
#  'kia': -3.2,
#  'kk': 1.5,
#  'kmuf': 2.2,
#  'l': 2.0,
#  'l&r': 2.2,
#  'laoj': 1.3,
#  'lmao': 2.9,
#  'lmbao': 1.8,
#  'lmfao': 2.5,
#  'lmso': 2.7,
#  'lol': 1.8,
#  'lolz': 2.7,
#  'lts': 1.6,
#  'ly': 2.6,
#  'ly4e': 2.7,
#  'lya': 3.3,
#  'lyb': 3.0,
#  'lyl': 3.1,
#  'lylab': 2.7,
#  'lylas': 2.6,
#  'lylb': 1.6,
#  'm8': 1.4,
#  'mia': -1.2,
#  'mml': 2.0,
#  'mofo': -2.4,
#  'muah': 2.3,
#  'mubar': -1.0,
#  'musm': 0.9,
#  'mwah': 2.5,
#  'n1': 1.9,
#  'nbd': 1.3,
#  'nbif': -0.5,
#  'nfc': -2.7,
#  'nfw': -2.4,
#  'nh': 2.2,
#  'nimby': -0.8,
#  'nimjd': -0.7,
#  'nimq': -0.2,
#  'nimy': -1.4,
#  'nitl': -1.5,
#  'nme': -2.1,
#  'noyb': -0.7,
#  'np': 1.4,
#  'ntmu': 1.4,
#  'o-8': -0.5,
#  'o-:': -0.3,
#  'o-|': -1.1,
#  'o.o': -0.8,
#  'O.o': -0.6,
#  'o.O': -0.6,
#  'o:': -0.2,
#  'o:)': 1.5,
#  'o:-)': 2.0,
#  'o:-3': 2.2,
#  'o:3': 2.3,
#  'o:<': -0.3,
#  'o;^)': 1.6,
#  'ok': 1.2,
#  'o_o': -0.5,
#  'O_o': -0.5,
#  'o_O': -0.5,
#  'pita': -2.4,
#  'pls': 0.3,
#  'plz': 0.3,
#  'pmbi': 0.8,
#  'pmfji': 0.3,
#  'pmji': 0.7,
#  'po': -2.6,
#  'ptl': 2.6,
#  'pu': -1.1,
#  'qq': -2.2,
#  'qt': 1.8,
#  'r&r': 2.4,
#  'rofl': 2.7,
#  'roflmao': 2.5,
#  'rotfl': 2.6,
#  'rotflmao': 2.8,
#  'rotflmfao': 2.5,
#  'rotflol': 3.0,
#  'rotgl': 2.9,
#  'rotglmao': 1.8,
#  's:': -1.1,
#  'sapfu': -1.1,
#  'sete': 2.8,
#  'sfete': 2.7,
#  'sgtm': 2.4,
#  'slap': 0.6,
#  'slaw': 2.1,
#  'smh': -1.3,
#  'snafu': -2.5,
#  'sob': -1.0,
#  'swak': 2.3,
#  'tgif': 2.3,
#  'thks': 1.4,
#  'thx': 1.5,
#  'tia': 2.3,
#  'tmi': -0.3,
#  'tnx': 1.1,
#  'true': 1.8,
#  'tx': 1.5,
#  'txs': 1.1,
#  'ty': 1.6,
#  'tyvm': 2.5,
#  'urw': 1.9,
#  'vbg': 2.1,
#  'vbs': 3.1,
#  'vip': 2.3,
#  'vwd': 2.6,
#  'vwp': 2.1,
#  'wag': -0.2,
#  'wd': 2.7,
#  'wilco': 0.9,
#  'wp': 1.0,
#  'wtf': -2.8,
#  'wtg': 2.1,
#  'wth': -2.4,
#  'x-d': 2.6,
#  'x-p': 1.7,
#  'xd': 2.8,
#  'xlnt': 3.0,
#  'xoxo': 3.0,
#  'xoxozzz': 2.3,
#  'xp': 1.6,
#  'xqzt': 1.6,
#  'xtc': 0.8,
#  'yolo': 1.1,
#  'yoyo': 0.4,
#  'yvw': 1.6,
#  'yw': 1.8,
#  'ywia': 2.5,
#  'zzz': -1.2,
#  '[-;': 0.5,
#  '[:': 1.3,
#  '[;': 1.0,
#  '[=': 1.7,
#  '\\-:': -1.0,
#  '\\:': -1.0,
#  '\\:<': -1.7,
#  '\\=': -1.1,
#  '\\^:': -1.3,
#  '\\o/': 2.2,
#  '\\o:': -1.2,
#  ']-:': -2.1,
#  ']:': -1.6,
#  ']:<': -2.5,
#  '^<_<': 1.4,
#  '^urs': -2.8,
#  'abandon': -1.9,
#  'abandoned': -2.0,
#  'abandoner': -1.9,
#  'abandoners': -1.9,
#  'abandoning': -1.6,
#  'abandonment': -2.4,
#  'abandonments': -1.7,
#  'abandons': -1.3,
#  'abducted': -2.3,
#  'abduction': -2.8,
#  'abductions': -2.0,
#  'abhor': -2.0,
#  'abhorred': -2.4,
#  'abhorrent': -3.1,
#  'abhors': -2.9,
#  'abilities': 1.0,
#  'ability': 1.3,
#  'aboard': 0.1,
#  'absentee': -1.1,
#  'absentees': -0.8,
#  'absolve': 1.2,
#  'absolved': 1.5,
#  'absolves': 1.3,
#  'absolving': 1.6,
#  'abuse': -3.2,
#  'abused': -2.3,
#  'abuser': -2.6,
#  'abusers': -2.6,
#  'abuses': -2.6,
#  'abusing': -2.0,
#  'abusive': -3.2,
#  'abusively': -2.8,
#  'abusiveness': -2.5,
#  'abusivenesses': -3.0,
#  'accept': 1.6,
#  'acceptabilities': 1.6,
#  'acceptability': 1.1,
#  'acceptable': 1.3,
#  'acceptableness': 1.3,
#  'acceptably': 1.5,
#  'acceptance': 2.0,
#  'acceptances': 1.7,
#  'acceptant': 1.6,
#  'acceptation': 1.3,
#  'acceptations': 0.9,
#  'accepted': 1.1,
#  'accepting': 1.6,
#  'accepts': 1.3,
#  'accident': -2.1,
#  'accidental': -0.3,
#  'accidentally': -1.4,
#  'accidents': -1.3,
#  'accomplish': 1.8,
#  'accomplished': 1.9,
#  'accomplishes': 1.7,
#  'accusation': -1.0,
#  'accusations': -1.3,
#  'accuse': -0.8,
#  'accused': -1.2,
#  'accuses': -1.4,
#  'accusing': -0.7,
#  'ache': -1.6,
#  'ached': -1.6,
#  'aches': -1.0,
#  'achievable': 1.3,
#  'aching': -2.2,
#  'acquit': 0.8,
#  'acquits': 0.1,
#  'acquitted': 1.0,
#  'acquitting': 1.3,
#  'acrimonious': -1.7,
#  'active': 1.7,
#  'actively': 1.3,
#  'activeness': 0.6,
#  'activenesses': 0.8,
#  'actives': 1.1,
#  'adequate': 0.9,
#  'admirability': 2.4,
#  'admirable': 2.6,
#  'admirableness': 2.2,
#  'admirably': 2.5,
#  'admiral': 1.3,
#  'admirals': 1.5,
#  'admiralties': 1.6,
#  'admiralty': 1.2,
#  'admiration': 2.5,
#  'admirations': 1.6,
#  'admire': 2.1,
#  'admired': 2.3,
#  'admirer': 1.8,
#  'admirers': 1.7,
#  'admires': 1.5,
#  'admiring': 1.6,
#  'admiringly': 2.3,
#  'admit': 0.8,
#  'admits': 1.2,
#  'admitted': 0.4,
#  'admonished': -1.9,
#  'adopt': 0.7,
#  'adopts': 0.7,
#  'adorability': 2.2,
#  'adorable': 2.2,
#  'adorableness': 2.5,
#  'adorably': 2.1,
#  'adoration': 2.9,
#  'adorations': 2.2,
#  'adore': 2.6,
#  'adored': 1.8,
#  'adorer': 1.7,
#  'adorers': 2.1,
#  'adores': 1.6,
#  'adoring': 2.6,
#  'adoringly': 2.4,
#  'adorn': 0.9,
#  'adorned': 0.8,
#  'adorner': 1.3,
#  'adorners': 0.9,
#  'adorning': 1.0,
#  'adornment': 1.3,
#  'adornments': 0.8,
#  'adorns': 0.5,
#  'advanced': 1.0,
#  'advantage': 1.0,
#  'advantaged': 1.4,
#  'advantageous': 1.5,
#  'advantageously': 1.9,
#  'advantageousness': 1.6,
#  'advantages': 1.5,
#  'advantaging': 1.6,
#  'adventure': 1.3,
#  'adventured': 1.3,
#  'adventurer': 1.2,
#  'adventurers': 0.9,
#  'adventures': 1.4,
#  'adventuresome': 1.7,
#  'adventuresomeness': 1.3,
#  'adventuress': 0.8,
#  'adventuresses': 1.4,
#  'adventuring': 2.3,
#  'adventurism': 1.5,
#  'adventurist': 1.4,
#  'adventuristic': 1.7,
#  'adventurists': 1.2,
#  'adventurous': 1.4,
#  'adventurously': 1.3,
#  'adventurousness': 1.8,
#  'adversarial': -1.5,
#  'adversaries': -1.0,
#  'adversary': -0.8,
#  'adversative': -1.2,
#  'adversatively': -0.1,
#  'adversatives': -1.0,
#  'adverse': -1.5,
#  'adversely': -0.8,
#  'adverseness': -0.6,
#  'adversities': -1.5,
#  'adversity': -1.8,
#  'affected': -0.6,
#  'affection': 2.4,
#  'affectional': 1.9,
#  'affectionally': 1.5,
#  'affectionate': 1.9,
#  'affectionately': 2.2,
#  'affectioned': 1.8,
#  'affectionless': -2.0,
#  'affections': 1.5,
#  'afflicted': -1.5,
#  'affronted': 0.2,
#  'aggravate': -2.5,
#  'aggravated': -1.9,
#  'aggravates': -1.9,
#  'aggravating': -1.2,
#  'aggress': -1.3,
#  'aggressed': -1.4,
#  'aggresses': -0.5,
#  'aggressing': -0.6,
#  'aggression': -1.2,
#  'aggressions': -1.3,
#  'aggressive': -0.6,
#  'aggressively': -1.3,
#  'aggressiveness': -1.8,
#  'aggressivities': -1.4,
#  'aggressivity': -0.6,
#  'aggressor': -0.8,
#  'aggressors': -0.9,
#  'aghast': -1.9,
#  'agitate': -1.7,
#  'agitated': -2.0,
#  'agitatedly': -1.6,
#  'agitates': -1.4,
#  'agitating': -1.8,
#  'agitation': -1.0,
#  'agitational': -1.2,
#  'agitations': -1.3,
#  'agitative': -1.3,
#  'agitato': -0.1,
#  'agitator': -1.4,
#  'agitators': -2.1,
#  'agog': 1.9,
#  'agonise': -2.1,
#  'agonised': -2.3,
#  'agonises': -2.4,
#  'agonising': -1.5,
#  'agonize': -2.3,
#  'agonized': -2.2,
#  'agonizes': -2.3,
#  'agonizing': -2.7,
#  'agonizingly': -2.3,
#  'agony': -1.8,
#  'agree': 1.5,
#  'agreeability': 1.9,
#  'agreeable': 1.8,
#  'agreeableness': 1.8,
#  'agreeablenesses': 1.3,
#  'agreeably': 1.6,
#  'agreed': 1.1,
#  'agreeing': 1.4,
#  'agreement': 2.2,
#  'agreements': 1.1,
#  'agrees': 0.8,
#  'alarm': -1.4,
#  'alarmed': -1.4,
#  'alarming': -0.5,
#  'alarmingly': -2.6,
#  'alarmism': -0.3,
#  'alarmists': -1.1,
#  'alarms': -1.1,
#  'alas': -1.1,
#  'alert': 1.2,
#  'alienation': -1.1,
#  'alive': 1.6,
#  'allergic': -1.2,
#  'allow': 0.9,
#  'alone': -1.0,
#  'alright': 1.0,
#  'amaze': 2.5,
#  'amazed': 2.2,
#  'amazedly': 2.1,
#  'amazement': 2.5,
#  'amazements': 2.2,
#  'amazes': 2.2,
#  'amazing': 2.8,
#  'amazon': 0.7,
#  'amazonite': 0.2,
#  'amazons': -0.1,
#  'amazonstone': 1.0,
#  'amazonstones': 0.2,
#  'ambitious': 2.1,
#  'ambivalent': 0.5,
#  'amor': 3.0,
#  'amoral': -1.6,
#  'amoralism': -0.7,
#  'amoralisms': -0.7,
#  'amoralities': -1.2,
#  'amorality': -1.5,
#  'amorally': -1.0,
#  'amoretti': 0.2,
#  'amoretto': 0.6,
#  'amorettos': 0.3,
#  'amorino': 1.2,
#  'amorist': 1.6,
#  'amoristic': 1.0,
#  'amorists': 0.1,
#  'amoroso': 2.3,
#  'amorous': 1.8,
#  'amorously': 2.3,
#  'amorousness': 2.0,
#  'amorphous': -0.2,
#  'amorphously': 0.1,
#  'amorphousness': 0.3,
#  'amort': -2.1,
#  'amortise': 0.5,
#  'amortised': -0.2,
#  'amortises': 0.1,
#  'amortizable': 0.5,
#  'amortization': 0.6,
#  'amortizations': 0.2,
#  'amortize': -0.1,
#  'amortized': 0.8,
#  'amortizes': 0.6,
#  'amortizing': 0.8,
#  'amusable': 0.7,
#  'amuse': 1.7,
#  'amused': 1.8,
#  'amusedly': 2.2,
#  'amusement': 1.5,
#  'amusements': 1.5,
#  'amuser': 1.1,
#  'amusers': 1.3,
#  'amuses': 1.7,
#  'amusia': 0.3,
#  'amusias': -0.4,
#  'amusing': 1.6,
#  'amusingly': 0.8,
#  'amusingness': 1.8,
#  'amusive': 1.7,
#  'anger': -2.7,
#  'angered': -2.3,
#  'angering': -2.2,
#  'angerly': -1.9,
#  'angers': -2.3,
#  'angrier': -2.3,
#  'angriest': -3.1,
#  'angrily': -1.8,
#  'angriness': -1.7,
#  'angry': -2.3,
#  'anguish': -2.9,
#  'anguished': -1.8,
#  'anguishes': -2.1,
#  'anguishing': -2.7,
#  'animosity': -1.9,
#  'annoy': -1.9,
#  'annoyance': -1.3,
#  'annoyances': -1.8,
#  'annoyed': -1.6,
#  'annoyer': -2.2,
#  'annoyers': -1.5,
#  'annoying': -1.7,
#  'annoys': -1.8,
#  'antagonism': -1.9,
#  'antagonisms': -1.2,
#  'antagonist': -1.9,
#  'antagonistic': -1.7,
#  'antagonistically': -2.2,
#  'antagonists': -1.7,
#  'antagonize': -2.0,
#  'antagonized': -1.4,
#  'antagonizes': -0.5,
#  'antagonizing': -2.7,
#  'anti': -1.3,
#  'anticipation': 0.4,
#  'anxieties': -0.6,
#  'anxiety': -0.7,
#  'anxious': -1.0,
#  'anxiously': -0.9,
#  'anxiousness': -1.0,
#  'aok': 2.0,
#  'apathetic': -1.2,
#  'apathetically': -0.4,
#  'apathies': -0.6,
#  'apathy': -1.2,
#  'apeshit': -0.9,
#  'apocalyptic': -3.4,
#  'apologise': 1.6,
#  'apologised': 0.4,
#  'apologises': 0.8,
#  'apologising': 0.2,
#  'apologize': 0.4,
#  'apologized': 1.3,
#  'apologizes': 1.5,
#  'apologizing': -0.3,
#  'apology': 0.2,
#  'appall': -2.4,
#  'appalled': -2.0,
#  'appalling': -1.5,
#  'appallingly': -2.0,
#  'appalls': -1.9,
#  'appease': 1.1,
#  'appeased': 0.9,
#  'appeases': 0.9,
#  'appeasing': 1.0,
#  'applaud': 2.0,
#  'applauded': 1.5,
#  'applauding': 2.1,
#  'applauds': 1.4,
#  'applause': 1.8,
#  'appreciate': 1.7,
#  'appreciated': 2.3,
#  'appreciates': 2.3,
#  'appreciating': 1.9,
#  'appreciation': 2.3,
#  'appreciations': 1.7,
#  'appreciative': 2.6,
#  'appreciatively': 1.8,
#  'appreciativeness': 1.6,
#  'appreciator': 2.6,
#  'appreciators': 1.5,
#  'appreciatory': 1.7,
#  'apprehensible': 1.1,
#  'apprehensibly': -0.2,
#  'apprehension': -2.1,
#  'apprehensions': -0.9,
#  'apprehensively': -0.3,
#  'apprehensiveness': -0.7,
#  'approval': 2.1,
#  'approved': 1.8,
#  'approves': 1.7,
#  'ardent': 2.1,
#  'arguable': -1.0,
#  'arguably': -1.0,
#  'argue': -1.4,
#  'argued': -1.5,
#  'arguer': -1.6,
#  'arguers': -1.4,
#  'argues': -1.6,
#  'arguing': -2.0,
#  'argument': -1.5,
#  'argumentative': -1.5,
#  'argumentatively': -1.8,
#  'argumentive': -1.5,
#  'arguments': -1.7,
#  'arrest': -1.4,
#  'arrested': -2.1,
#  'arrests': -1.9,
#  'arrogance': -2.4,
#  'arrogances': -1.9,
#  'arrogant': -2.2,
#  'arrogantly': -1.8,
#  'ashamed': -2.1,
#  'ashamedly': -1.7,
#  'ass': -2.5,
#  'assassination': -2.9,
#  'assassinations': -2.7,
#  'assault': -2.8,
#  'assaulted': -2.4,
#  'assaulting': -2.3,
#  'assaultive': -2.8,
#  'assaults': -2.5,
#  'asset': 1.5,
#  'assets': 0.7,
#  'assfucking': -2.5,
#  'assholes': -2.8,
#  'assurance': 1.4,
#  'assurances': 1.4,
#  'assure': 1.4,
#  'assured': 1.5,
#  'assuredly': 1.6,
#  'assuredness': 1.4,
#  'assurer': 0.9,
#  'assurers': 1.1,
#  'assures': 1.3,
#  'assurgent': 1.3,
#  'assuring': 1.6,
#  'assuror': 0.5,
#  'assurors': 0.7,
#  'astonished': 1.6,
#  'astound': 1.7,
#  'astounded': 1.8,
#  'astounding': 1.8,
#  'astoundingly': 2.1,
#  'astounds': 2.1,
#  'attachment': 1.2,
#  'attachments': 1.1,
#  'attack': -2.1,
#  'attacked': -2.0,
#  'attacker': -2.7,
#  'attackers': -2.7,
#  'attacking': -2.0,
#  'attacks': -1.9,
#  'attract': 1.5,
#  'attractancy': 0.9,
#  'attractant': 1.3,
#  'attractants': 1.4,
#  'attracted': 1.8,
#  'attracting': 2.1,
#  'attraction': 2.0,
#  'attractions': 1.8,
#  'attractive': 1.9,
#  'attractively': 2.2,
#  'attractiveness': 1.8,
#  'attractivenesses': 2.1,
#  'attractor': 1.2,
#  'attractors': 1.2,
#  'attracts': 1.7,
#  'audacious': 0.9,
#  'authority': 0.3,
#  'aversion': -1.9,
#  'aversions': -1.1,
#  'aversive': -1.6,
#  'aversively': -0.8,
#  'avert': -0.7,
#  'averted': -0.3,
#  'averts': -0.4,
#  'avid': 1.2,
#  'avoid': -1.2,
#  'avoidance': -1.7,
#  'avoidances': -1.1,
#  'avoided': -1.4,
#  'avoider': -1.8,
#  'avoiders': -1.4,
#  'avoiding': -1.4,
#  'avoids': -0.7,
#  'await': 0.4,
#  'awaited': -0.1,
#  'awaits': 0.3,
#  'award': 2.5,
#  'awardable': 2.4,
#  'awarded': 1.7,
#  'awardee': 1.8,
#  'awardees': 1.2,
#  'awarder': 0.9,
#  'awarders': 1.3,
#  'awarding': 1.9,
#  'awards': 2.0,
#  'awesome': 3.1,
#  'awful': -2.0,
#  'awkward': -0.6,
#  'awkwardly': -1.3,
#  'awkwardness': -0.7,
#  'axe': -0.4,
#  'axed': -1.3,
#  'backed': 0.1,
#  'backing': 0.1,
#  'backs': -0.2,
#  'bad': -2.5,
#  'badass': 1.4,
#  'badly': -2.1,
#  'bailout': -0.4,
#  'bamboozle': -1.5,
#  'bamboozled': -1.5,
#  'bamboozles': -1.5,
#  'ban': -2.6,
#  'banish': -1.9,
#  'bankrupt': -2.6,
#  'bankster': -2.1,
#  'banned': -2.0,
#  'bargain': 0.8,
#  'barrier': -0.5,
#  'bashful': -0.1,
#  'bashfully': 0.2,
#  'bashfulness': -0.8,
#  'bastard': -2.5,
#  'bastardies': -1.8,
#  'bastardise': -2.1,
#  'bastardised': -2.3,
#  'bastardises': -2.3,
#  'bastardising': -2.6,
#  'bastardization': -2.4,
#  'bastardizations': -2.1,
#  'bastardize': -2.4,
#  'bastardized': -2.0,
#  'bastardizes': -1.8,
#  'bastardizing': -2.3,
#  'bastardly': -2.7,
#  'bastards': -3.0,
#  'bastardy': -2.7,
#  'battle': -1.6,
#  'battled': -1.2,
#  'battlefield': -1.6,
#  'battlefields': -0.9,
#  'battlefront': -1.2,
#  'battlefronts': -0.8,
#  'battleground': -1.7,
#  'battlegrounds': -0.6,
#  'battlement': -0.4,
#  'battlements': -0.4,
#  'battler': -0.8,
#  'battlers': -0.2,
#  'battles': -1.6,
#  'battleship': -0.1,
#  'battleships': -0.5,
#  'battlewagon': -0.3,
#  'battlewagons': -0.5,
#  'battling': -1.1,
#  'beaten': -1.8,
#  'beatific': 1.8,
#  'beating': -2.0,
#  'beaut': 1.6,
#  'beauteous': 2.5,
#  'beauteously': 2.6,
#  ...}

# %%
print(Analyser.polarity_scores('omegalul'))
# Out:
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.1103}

# %%
print(Analyser.lexicon['❌'])
# Out:
# 0.29
